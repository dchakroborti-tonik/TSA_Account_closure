# %% [markdown]
# # <div align="center" style="color: #ff5733;">TSA Closure Third Notification</div>

# %%
# Import Libraries   

import pandas as pd  
import numpy as np  

from google.cloud import bigquery
import os

path = r"C:\Users\DwaipayanChakroborti\AppData\Roaming\gcloud\legacy_credentials\dchakroborti@tonikbank.com\adc.json"

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = path
client = bigquery.Client(project="prj-prod-dataplatform")

# %% [markdown]
# # Ask Balasubramani to refresh risk_credit_mis.tsa_account_closure table.
# **Check if that is refreshed when Balasubramani confirms it**

# %%
sq = """select Run_Date, count(1)cnt from risk_credit_mis.tsa_account_closure group by 1 order by 1 desc"""
df = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')
df.head(1)
# Out:
# Job ID 039218d6-04a0-4390-b73d-c267d9e2aae4 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
#      Run_Date     cnt
# 0  2024-08-06  643163

# %% [markdown]
# The date should show yesterday's date

# %% [markdown]
# # Read the data from the first sheet for Type1 and Type2 data provided by Marvin

# %%
d1 = pd.read_excel(r"C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Marvin\TSA Account Closure\May24&June24 Ongoing Batch\ThirdNotification_files\Type 1 & 2 - 2nd Notif20240807.xlsx")
d1.shape
# Out:
# (14177, 2)

# %%
print(f"The unique count of customer_id is:\t{len(d1['Customer_Id'].unique())}")
d1.head()
# Out:
# The unique count of customer_id is:	14177
#    Customer_Id ACTION_TYPE
# 0      2493151      TYPE 1
# 1      2446923      TYPE 1
# 2      2491508      TYPE 1
# 3      2475440      TYPE 1
# 4      2484055      TYPE 1

# %% [markdown]
# # Read the data from the second sheet for Type3 data provided by Marvin

# %%
d2 = pd.read_excel(r"C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Marvin\TSA Account Closure\May24&June24 Ongoing Batch\ThirdNotification_files\Type 3 - 2nd Notif20240807.xlsx")
d2.shape
# Out:
# (1328, 2)

# %%
print(f"The unique count of customer_id is:\t{len(d2['Customer_Id'].unique())}")
d2.head()
# Out:
# The unique count of customer_id is:	1328
#    Customer_Id ACTION_TYPE
# 0      2276581      TYPE 3
# 1      1671759      TYPE 3
# 2      2253135      TYPE 3
# 3      2187964      TYPE 3
# 4      2253528      TYPE 3

# %%
result = pd.concat([d1, d2], axis=0, ignore_index=True)
result.shape
# Out:
# (15505, 2)

# %%
result.ACTION_TYPE.value_counts()
# Out:
# ACTION_TYPE
# TYPE 1    14149
# TYPE 3     1328
# TYPE 2       28
# Name: count, dtype: int64

# %%
result[result['Customer_Id'] == '1671759']
# Out:
#       Customer_Id ACTION_TYPE
# 14178     1671759      TYPE 3

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15505 entries, 0 to 15504
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer_Id  15505 non-null  int64
#  1   ACTION_TYPE  15505 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 242.4+ KB

# %%
result['Customer_Id'] = result['Customer_Id'].astype(str)
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15505 entries, 0 to 15504
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer_Id  15505 non-null  object
#  1   ACTION_TYPE  15505 non-null  object
# dtypes: object(2)
# memory usage: 242.4+ KB

# %%
result.to_csv("temp.csv", index = False)

# %%
a = tuple(result['Customer_Id'])
a[:5]
# Out:
# ('2493151', '2446923', '2491508', '2475440', '2484055')

# %%
d = '2024-08-07'   ### Need to change this to D-1 everytime we run this code ###
# Get the current date
current_date = pd.Timestamp.now().date()
d_minus_1_days = current_date - pd.DateOffset(days=1)
# Calculate D-60 days
d_minus_60_days = '2024-05-08'
# Calculate D-180 days
d_minus_180_days = '2024-01-09'

print("D-1 day from current date", d_minus_1_days )
print("D-60 day from the current date - 1:", d_minus_60_days)
print("D-180 day from the current date -1:", d_minus_180_days)

d_minus_1_days_string = d_minus_1_days.strftime('%Y-%m-%d')
print("D-1 day from the current date:", d_minus_1_days_string)

d_minus_60_days_string = d_minus_60_days
print("D-60 day from the current date:", d_minus_60_days_string)

d_minus_180_days_string = d_minus_180_days
print("D-180 day from the current date:", d_minus_180_days_string)
# Out:
# D-1 day from current date 2024-08-06 00:00:00
# D-60 day from the current date - 1: 2024-05-08
# D-180 day from the current date -1: 2024-01-09
# D-1 day from the current date: 2024-08-06
# D-60 day from the current date: 2024-05-08
# D-180 day from the current date: 2024-01-09

# %% [markdown]
# Step1: At line 11 change the date to D-1<br><br>
# Step2: At line around 36 (and (TSA_Opening_date < date '2023-10-18')   ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)) Change the date D-60 Days <br><br>
# Step3: At line around 45 (WHEN tsa_status = 'Active' and Last_TSA_EOD_Balance_Date is null and (TSA_Opening_date < date '2023-10-18')  ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)) Change the date D-60 Days <br><br>
# Step4: At line 58 (and TSA_Opening_date < date '2023-06-18'  and (Last_TSA_Credit_Date < date '2023-06-18' and Last_TSA_Debit_Date < date '2023-06-18' and coalesce(Last_Group_Stash_Credit_Date,date '1970-01-01') < date '2023-06-18')  ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)) <br><br>
# Step5: At line 72 (Run_Date = date '2024-01-09'###DATE change here to D-1) Change the date to D-1<br><br>

# %% [markdown]
# First Notification we change all the steps <br><br>
# Second and Third Notification we only change Step1 and Step5
# For Second Notificaiton and Third Notificaiton the customre id should be from the file sent by Marvin. <br><br>

# %%
sq = f"""
with
w_kyc
as
(
  select distinct PARTYID, SEGCATEGORYDESC, row_number() over(partition by partyid order by SEGEFFECTIVEFROM desc) as rnk from `core_raw.party_details`
),
w_tsa
as
(
  select * from risk_credit_mis.tsa_account_closure where Run_Date = date '{d_minus_1_days_string}' ###DATE change here to D-1
  and
  Customer_Id not in (select cast(PARTYID as string) from w_kyc where rnk = 1 and SEGCATEGORYDESC = 'BKYC')
  and
  --customer_id in (select cast(customer_id as string) from prj-prod-dataplatform.dap_ds_poweruser_playground.tsa_2nd_notification_base_10jan2024)
  customer_id in {a}
)
select * from w_tsa;
"""

dfd = client.query(sq).to_dataframe(progress_bar_type =  'tqdm')
dfd.shape
# Out:
# (15504, 29)

# %%
sq = f"""
with
w_kyc
as
(
  select distinct PARTYID, SEGCATEGORYDESC, row_number() over(partition by partyid order by SEGEFFECTIVEFROM desc) as rnk from `core_raw.party_details`
),
w_tsa
as
(
  select * from risk_credit_mis.tsa_account_closure where Run_Date = date '{d_minus_1_days_string}'  ###DATE change here to D-1
  and
  Customer_Id not in (select cast(PARTYID as string) from w_kyc where rnk = 1 and SEGCATEGORYDESC = 'BKYC')
  and
  --customer_id in (select cast(customer_id as string) from prj-prod-dataplatform.dap_ds_poweruser_playground.tsa_2nd_notification_base_10jan2024)
  customer_id in {a}
),
w_approved
as
(
  select DISTINCT customerId from risk_credit_mis.loan_master_table where loantype = 'BIGLOAN' OR FLAGAPPROVAL = 1 OR FLAGDISBURSEMENT = 1  
  or (stage1Status = 'EXPIRED' AND cddInitiatedDateAndTime IS NULL)
)
select *
from
(
  select distinct
  a.Customer_Id,a.TSA_Opening_date,
  c.OFSTANDARDACCOUNTID as TSA_Account_Number, c.OfblockAmount, 
  a.TSA_Status,a.TSA_Balance,a.Solo_Stash_Balance,a.Group_Stash_Balance,a.Term_Deposit_Balance,a.Active_Term_Deposit_flag,a.Last_TSA_Credit_Date,a.Last_TSA_Debit_Date,
  a.ARI_Flag,a.Active_Loan,a.Total_Loan_Outstanding,  case when b.customerId is not null then 1 else 0 end as Approved_Loans,
  a.Pending_Loan_Applications,a.Hard_Reject_Loans_App,a.Soft_Reject_Loans_App,a.Cancelled_Loans_App, extract(date from a.Last_Login_Date) as Last_Login_Date,
  a.Last_TSA_EOD_Balance_Date,a.Last_Group_Stash_Credit_Date,a.Group_Stash_Balance_Owner,a.Run_Date,a.Batch,a.Processing_Month,a.pending_loans_not_expired_not_exempt,a.expired_loans,
  a.pending_loans_lastDt,a.expired_loans_lastDt,
  CASE 
    WHEN tsa_status = 'Active' and (Last_TSA_Credit_Date = date '1970-01-01' and Last_Group_Stash_Credit_Date is null)
    and (TSA_Opening_date < date '{d_minus_60_days_string}')   ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
    and ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) = 0 )
    and (Active_Loan = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
    and (Active_Term_Deposit_flag = 0)
    and (ARI_Flag = 'N')
    --and (Approved_Loans = 0)  THEN 'TYPE 1'
    and b.customerId is null  THEN 'TYPE 1'


    WHEN tsa_status = 'Active' and Last_TSA_EOD_Balance_Date is null and (TSA_Opening_date < date '{d_minus_60_days_string}')  ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
    and ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) = 0 )
    and (Active_Loan = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
    and (Active_Term_Deposit_flag = 0)
    and (ARI_Flag = 'N')
    --and (Approved_Loans = 0)
    and b.customerId is null  
    and (date_trunc(TSA_Opening_date,day) = date_trunc(Last_Login_Date,day)) THEN 'TYPE 2'

    
    WHEN ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) < 1 )
            and (Active_Loan = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
            and (Active_Term_Deposit_flag = 0)
            and TSA_Opening_date < date '{d_minus_180_days_string}'                                     ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
            and (Last_TSA_Credit_Date < date '{d_minus_180_days_string}'                                 ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
            and Last_TSA_Debit_Date < date '{d_minus_180_days_string}'                                         ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
            and coalesce(Last_Group_Stash_Credit_Date,date '1970-01-01') < date '{d_minus_180_days_string}' )  ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
            and tsa_status = 'Active'
            and (ARI_Flag = 'N')
    --and (Approved_Loans = 0)
            and b.customerId is null  
    THEN 'TYPE 3'
    ELSE 'NO ACTION'
    END AS ACTION_TYPE
  from w_tsa A
  left join w_approved b
  on cast(a.Customer_Id as int64) = b.customerId
  left join core_raw.customer_accounts c
  on c.OFCUSTOMERID = a.Customer_Id and c.CRINTERDESC = 'Transactional Savings Account Inv_R' and c.OFISCLOSED = 'N'
  where
  Run_Date = date '{d_minus_1_days_string}'  ###DATE change here to D-1
)
"""

# %%
print(sq)
# Out:
# with
# w_kyc
# as
# (
#   select distinct PARTYID, SEGCATEGORYDESC, row_number() over(partition by partyid order by SEGEFFECTIVEFROM desc) as rnk from `core_raw.party_details`
# ),
# w_tsa
# as
# (
#   select * from risk_credit_mis.tsa_account_closure where Run_Date = date '2024-08-06'  ###DATE change here to D-1
#   and
#   Customer_Id not in (select cast(PARTYID as string) from w_kyc where rnk = 1 and SEGCATEGORYDESC = 'BKYC')
#   and
#   --customer_id in (select cast(customer_id as string) from prj-prod-dataplatform.dap_ds_poweruser_playground.tsa_2nd_notification_base_10jan2024)
#   customer_id in ('2493151', '2446923', '2491508', '2475440', '2484055', '2462679', '2498223', '2449420', '2471381', '2479571', '2487885', '2473153', '2378191', '2503107', '2484755', '2468032', '2465402', '2495091', '2449256', '2478942', '2492904', '2486579', '2460761', '2502195', '2446759', '2467481', '2477966', '2498293', '2494796', '2461774', '2446152', '2430218', '2454989', '2481663', '2480724', '2450351', '2490956', '2472297', '2479041', '2497327', '2474749', '2476312', '2476120', '1347338', '1803316', '2457846', '2481080', '2490675', '2401189', '2454156', '2485804', '2482246', '2501557', '2500876', '2500212', '2468939', '2447147', '2485834', '2445688', '2475673', '2453590', '2465357', '2468190', '2476091', '2464467', '2462799', '2467678', '2454671', '2453316', '2453734', '2456718', '2475113', '2468725', '2496489', '2443534', '2448696', '2463021', '2452815', '2458517', '2475715', '2482507', '2471836', '2200579', '2434996', '2489338', '2469934', '2445706', '2446998', '2474925', '2448143', '2447776', '2461634', '2468530', '2472698', '2466773', '2495531', '2444339', '2482712', '2474282', '2482025', '2365935', '2479283', '2446465', '2470469', '2460986', '2307176', '1576258', '2500267', '2492228', '2460694', '2393130', '2452060', '2468853', '2463407', '2484514', '2446829', '2446600', '2493565', '2444418', '2475927', '2471654', '2494313', '2463538', '2484773', '2491755', '2478580', '2486157', '2482347', '2445358', '2477507', '2454151', '2471044', '2357862', '2451267', '2480953', '2468929', '1199433', '2462178', '2448090', '2453816', '2494536', '2447266', '2491864', '2476027', '2385095', '2451166', '2456494', '2495071', '2464401', '2456391', '2485714', '2412585', '2466613', '2479182', '2474892', '2497980', '2463824', '2457900', '2443919', '2490321', '2463309', '2454653', '2454467', '2463479', '2471045', '2443240', '2475049', '2503202', '2462506', '2448157', '2355322', '2462605', '2486152', '2448170', '2471042', '2501891', '2458716', '2477365', '2461906', '2456250', '2473444', '2494552', '2502017', '2464640', '2366012', '2447928', '2461413', '2501698', '2485526', '2469910', '2460831', '2447427', '2499074', '2493695', '2484601', '2242596', '2483865', '2472213', '2484412', '2479195', '2468784', '2471687', '2481947', '2487524', '2482143', '2454003', '2477422', '2450313', '2494772', '2462550', '2480837', '2286205', '2477298', '2466020', '2474211', '2428381', '2479058', '2497997', '2473375', '2444182', '2264766', '2488652', '2447241', '2498640', '2390460', '2466412', '2442901', '2443528', '2275279', '2452317', '2459003', '2180570', '2452010', '2486326', '1613903', '2476057', '2473914', '2495392', '2479659', '2462166', '2486942', '2458339', '2451749', '2452128', '2502620', '2442943', '2455025', '2493103', '2395131', '2493571', '2479024', '2397581', '2442250', '2488735', '2458924', '2446092', '2468915', '2500328', '2465084', '2456419', '2476628', '2472620', '2472565', '2465675', '2475796', '2476286', '2489250', '2453387', '2461562', '2459429', '2371220', '2458730', '2501361', '2502397', '2444537', '2473606', '2477899', '2493978', '2502225', '2479314', '2478047', '2445732', '2496673', '2462551', '2497592', '2468792', '2457409', '2478766', '2449066', '2208962', '2464489', '2467992', '2317357', '2452558', '2492233', '2499178', '2468486', '2459989', '2450689', '2467280', '2472761', '2452766', '2484076', '2461511', '2482297', '2450682', '2480890', '2442915', '2447310', '2493807', '2444578', '2494959', '2455468', '2447719', '2478848', '1280339', '2465997', '2433147', '2468965', '2470724', '2501172', '2464568', '2450902', '2483402', '1219050', '2485663', '2465169', '2485401', '2496941', '2486143', '2483637', '2496453', '2492926', '2482745', '2408780', '2219903', '2480732', '2483667', '2413638', '2478969', '2457361', '2465785', '2142615', '2492169', '2443915', '2458743', '2460431', '2469819', '2443874', '2472989', '2493294', '2482028', '2492563', '2448067', '2494529', '2449421', '2462813', '2472623', '2498057', '2475683', '2461437', '2448832',  ...
# ),
# w_approved
# as
# (
#   select DISTINCT customerId from risk_credit_mis.loan_master_table where loantype = 'BIGLOAN' OR FLAGAPPROVAL = 1 OR FLAGDISBURSEMENT = 1
#   or (stage1Status = 'EXPIRED' AND cddInitiatedDateAndTime IS NULL)
# )
# select *
# from
# (
#   select distinct
#   a.Customer_Id,a.TSA_Opening_date,
#   c.OFSTANDARDACCOUNTID as TSA_Account_Number, c.OfblockAmount,
#   a.TSA_Status,a.TSA_Balance,a.Solo_Stash_Balance,a.Group_Stash_Balance,a.Term_Deposit_Balance,a.Active_Term_Deposit_flag,a.Last_TSA_Credit_Date,a.Last_TSA_Debit_Date,
#   a.ARI_Flag,a.Active_Loan,a.Total_Loan_Outstanding,  case when b.customerId is not null then 1 else 0 end as Approved_Loans,
#   a.Pending_Loan_Applications,a.Hard_Reject_Loans_App,a.Soft_Reject_Loans_App,a.Cancelled_Loans_App, extract(date from a.Last_Login_Date) as Last_Login_Date,
#   a.Last_TSA_EOD_Balance_Date,a.Last_Group_Stash_Credit_Date,a.Group_Stash_Balance_Owner,a.Run_Date,a.Batch,a.Processing_Month,a.pending_loans_not_expired_not_exempt,a.expired_loans,
#   a.pending_loans_lastDt,a.expired_loans_lastDt,
#   CASE
#     WHEN tsa_status = 'Active' and (Last_TSA_Credit_Date = date '1970-01-01' and Last_Group_Stash_Credit_Date is null)
#     and (TSA_Opening_date < date '2024-05-08')   ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#     and ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) = 0 )
#     and (Active_Loan = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
#     and (Active_Term_Deposit_flag = 0)
#     and (ARI_Flag = 'N')
#     --and (Approved_Loans = 0)  THEN 'TYPE 1'
#     and b.customerId is null  THEN 'TYPE 1'
#
#
#     WHEN tsa_status = 'Active' and Last_TSA_EOD_Balance_Date is null and (TSA_Opening_date < date '2024-05-08')  ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#     and ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) = 0 )
#     and (Active_Loan = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
#     and (Active_Term_Deposit_flag = 0)
#     and (ARI_Flag = 'N')
#     --and (Approved_Loans = 0)
#     and b.customerId is null
#     and (date_trunc(TSA_Opening_date,day) = date_trunc(Last_Login_Date,day)) THEN 'TYPE 2'
#
#
#     WHEN ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) < 1 )
#             and (Active_Loan = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
#             and (Active_Term_Deposit_flag = 0)
#             and TSA_Opening_date < date '2024-01-09'                                     ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#             and (Last_TSA_Credit_Date < date '2024-01-09'                                 ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#             and Last_TSA_Debit_Date < date '2024-01-09'                                         ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#             and coalesce(Last_Group_Stash_Credit_Date,date '1970-01-01') < date '2024-01-09' )  ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#             and tsa_status = 'Active'
#             and (ARI_Flag = 'N')
#     --and (Approved_Loans = 0)
#             and b.customerId is null
#     THEN 'TYPE 3'
#     ELSE 'NO ACTION'
#     END AS ACTION_TYPE
#   from w_tsa A
#   left join w_approved b
#   on cast(a.Customer_Id as int64) = b.customerId
#   left join core_raw.customer_accounts c
#   on c.OFCUSTOMERID = a.Customer_Id and c.CRINTERDESC = 'Transactional Savings Account Inv_R' and c.OFISCLOSED = 'N'
#   where
#   Run_Date = date '2024-08-06'  ###DATE change here to D-1
# )

# %%
df = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')
# Out:
# Job ID 41bb8eb3-ea56-48fa-8e2d-892e22368d6a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|

# %%
pd.set_option('display.max_columns', None)
df.sample(10)
# Out:
#       Customer_Id TSA_Opening_date TSA_Account_Number  OfblockAmount  \
# 15143     2498376       2024-05-05     60824983760008            0.0
# 13178     2489341       2024-05-07     60824893410006            0.0
# 4048      2449391       2024-04-02     60824493910006            0.0
# 8461      2477522       2024-04-23     60824775220006            0.0
# 13976     2493833       2024-05-02     60824938330002            0.0
# 13960     2465146       2024-04-14     60824651460009            0.0
# 2166      2486860       2024-04-28     60824868600002            0.0
# 8533      2454192       2024-04-06     60824541920006            0.0
# 13478     2476392       2024-04-22     60824763920001            0.0
# 7655      2413225       2024-02-27     60824132250004            0.0
#
#       TSA_Status  TSA_Balance  Solo_Stash_Balance  Group_Stash_Balance  \
# 15143     Active          0.0                 0.0                  0.0
# 13178     Active          0.0                 0.0                  0.0
# 4048      Active          0.0                 0.0                  0.0
# 8461      Active          0.0                 0.0                  0.0
# 13976     Active          0.0                 0.0                  0.0
# 13960     Active          0.0                 0.0                  0.0
# 2166      Active          0.0                 0.0                  0.0
# 8533      Active          0.0                 0.0                  0.0
# 13478     Active          0.0                 0.0                  0.0
# 7655      Active          0.0                 0.0                  0.0
#
#        Term_Deposit_Balance  Active_Term_Deposit_flag Last_TSA_Credit_Date  \
# 15143                   0.0                         0           1970-01-01
# 13178                   0.0                         0           1970-01-01
# 4048                    0.0                         0           1970-01-01
# 8461                    0.0                         0           1970-01-01
# 13976                   0.0                         0           1970-01-01
# 13960                   0.0                         0           1970-01-01
# 2166                    0.0                         0           1970-01-01
# 8533                    0.0                         0           1970-01-01
# 13478                   0.0                         0           1970-01-01
# 7655                    0.0                         0           1970-01-01
#
#       Last_TSA_Debit_Date ARI_Flag  Active_Loan  Total_Loan_Outstanding  \
# 15143          1970-01-01        N            0                     0.0
# 13178          1970-01-01        N            0                     0.0
# 4048           1970-01-01        N            0                     0.0
# 8461           1970-01-01        N            0                     0.0
# 13976          1970-01-01        N            0                     0.0
# 13960          1970-01-01        N            0                     0.0
# 2166           1970-01-01        N            0                     0.0
# 8533           1970-01-01        N            0                     0.0
# 13478          1970-01-01        N            0                     0.0
# 7655           1970-01-01        N            0                     0.0
#
#        Approved_Loans  Pending_Loan_Applications  Hard_Reject_Loans_App  \
# 15143               0                          0                      0
# 13178               0                          0                      0
# 4048                0                          0                      0
# 8461                0                          0                      0
# 13976               0                          0                      0
# 13960               0                          0                      0
# 2166                0                          0                      0
# 8533                0                          0                      0
# 13478               0                          0                      0
# 7655                0                          0                      0
#
#        Soft_Reject_Loans_App  Cancelled_Loans_App Last_Login_Date  \
# 15143                      0                    0      2024-07-07
# 13178                      0                    0      2024-05-07
# 4048                       0                    0      2024-04-02
# 8461                       0                    0      2024-04-23
# 13976                      0                    0      2024-05-02
# 13960                      0                    0      2024-07-04
# 2166                       0                    0      2024-04-28
# 8533                       0                    0      2024-04-06
# 13478                      0                    0      2024-06-19
# 7655                       1                    0      2024-06-28
#
#       Last_TSA_EOD_Balance_Date Last_Group_Stash_Credit_Date  \
# 15143                       NaT                          NaT
# 13178                       NaT                          NaT
# 4048                        NaT                          NaT
# 8461                        NaT                          NaT
# 13976                       NaT                          NaT
# 13960                       NaT                          NaT
# 2166                        NaT                          NaT
# 8533                        NaT                          NaT
# 13478                       NaT                          NaT
# 7655                        NaT                          NaT
#
#        Group_Stash_Balance_Owner    Run_Date    Batch Processing_Month  \
# 15143                        NaN  2024-08-06  Batch_1           August
# 13178                        NaN  2024-08-06  Batch_1           August
# 4048                         NaN  2024-08-06  Batch_1           August
# 8461                         NaN  2024-08-06  Batch_1           August
# 13976                        NaN  2024-08-06  Batch_1           August
# 13960                        NaN  2024-08-06  Batch_1           August
# 2166                         NaN  2024-08-06  Batch_1           August
# 8533                         NaN  2024-08-06  Batch_1           August
# 13478                        NaN  2024-08-06  Batch_1           August
# 7655                         NaN  2024-08-06  Batch_1           August
#
#        pending_loans_not_expired_not_exempt  expired_loans  \
# 15143                                     0              1
# 13178                                     0              1
# 4048                                      0              1
# 8461                                      0              1
# 13976                                     0              0
# 13960                                     0              0
# 2166                                      0              1
# 8533                                      0              0
# 13478                                     0              1
# 7655                                      0              1
#
#       pending_loans_lastDt expired_loans_lastDt ACTION_TYPE
# 15143                  NaT           2024-08-03      TYPE 1
# 13178                  NaT           2024-07-29      TYPE 1
# 4048                   NaT           2024-07-02      TYPE 1
# 8461                   NaT           2024-07-23      TYPE 1
# 13976                  NaT                  NaT      TYPE 1
# 13960                  NaT                  NaT      TYPE 1
# 2166                   NaT           2024-07-28      TYPE 1
# 8533                   NaT                  NaT      TYPE 1
# 13478                  NaT           2024-07-22      TYPE 1
# 7655                   NaT           2024-05-28      TYPE 1

# %%
df.shape
# Out:
# (15504, 32)

# %%
df['ACTION_TYPE'].value_counts()
# Out:
# ACTION_TYPE
# TYPE 1       14062
# TYPE 3        1216
# NO ACTION      198
# TYPE 2          28
# Name: count, dtype: int64

# %%
df.to_excel(r"C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Marvin\TSA Account Closure\May24&June24 Ongoing Batch\ThirdNotification_files\20240807_TSA_Account_Closure_3rdtNotification.xlsx", sheet_name='TSA_Closure_3rdNotification', index = False)
