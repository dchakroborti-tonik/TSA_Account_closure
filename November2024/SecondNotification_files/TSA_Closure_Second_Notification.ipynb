# %% [markdown]
# # <div align="center" style="color: #ff5733;">TSA Closure Second Notification</div>

# %%
# Import Libraries   

import pandas as pd  
import numpy as np  

from google.cloud import bigquery
import os

path = r"C:\Users\DwaipayanChakroborti\AppData\Roaming\gcloud\legacy_credentials\dchakroborti@tonikbank.com\adc.json"

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = path
client = bigquery.Client(project="prj-prod-dataplatform")

# %% [markdown]
# # Ask Balasubramani to refresh risk_credit_mis.tsa_account_closure table.
# **Check if that is refreshed when Balasubramani confirms it**

# %%
sq = """select Run_Date, count(1)cnt from risk_credit_mis.tsa_account_closure group by 1 order by 1 desc"""
df = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')
df.head(1)
# Out:
# Job ID 5a934546-1db5-448f-aade-227c4c7515d0 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
#      Run_Date     cnt
# 0  2024-11-14  731053

# %% [markdown]
# The date should show yesterday's date

# %% [markdown]
# # Read the data from the first sheet for Type1 and Type2 data provided by Marvin

# %%
d1 = pd.read_excel(r"C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Marvin\TSA Account Closure\November2024\SecondNotification_files\Dormant - Type 1 & 2.xlsx", sheet_name='Sheet1')
d1.shape
# Out:
# (61683, 2)

# %%
d1.columns
d1.rename(columns= {'partyid':'Customer_Id', 'Tagging':'ACTION_TYPE'}, inplace = True)

# %%
print(f"The unique count of customer_id is:\t{len(d1['Customer_Id'].unique())}")
d1.head()
# Out:
# The unique count of customer_id is:	61683
#    Customer_Id ACTION_TYPE
# 0      1127684  Type 1 & 2
# 1      1127547  Type 1 & 2
# 2      1128241  Type 1 & 2
# 3      1128145  Type 1 & 2
# 4      1128222  Type 1 & 2

# %% [markdown]
# # Read the data from the second sheet for Type3 data provided by Marvin

# %%
d2 = pd.read_excel(r"C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Marvin\TSA Account Closure\September2024\SecondNotification_files\Type 3 - Sept 16.xlsx", sheet_name='Sheet1')
d2.shape
# Out:
# (1056, 2)

# %%
print(f"The unique count of customer_id is:\t{len(d2['Customer_Id'].unique())}")
d2.head()
# Out:
# The unique count of customer_id is:	1056
#    Customer_Id ACTION_TYPE
# 0      2345254      TYPE 3
# 1      2383814      TYPE 3
# 2      2370821      TYPE 3
# 3      2393414      TYPE 3
# 4      2410202      TYPE 3

# %%
result = pd.concat([d1, d2], axis=0, ignore_index=True)
result.shape
# Out:
# (27386, 2)

# %%
result = d1.copy()

# %%
result.ACTION_TYPE.value_counts()
# Out:
# ACTION_TYPE
# Type 1 & 2    61683
# Name: count, dtype: int64

# %%
result[result['Customer_Id'] == '1128222']
# Out:
#   Customer_Id ACTION_TYPE
# 4     1128222  Type 1 & 2

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61683 entries, 0 to 61682
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer_Id  61683 non-null  int64
#  1   ACTION_TYPE  61683 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 963.9+ KB

# %%
result['Customer_Id'] = result['Customer_Id'].astype(str)
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61683 entries, 0 to 61682
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer_Id  61683 non-null  object
#  1   ACTION_TYPE  61683 non-null  object
# dtypes: object(2)
# memory usage: 963.9+ KB

# %%
result.to_csv("temp.csv", index = False)

# %%
a = tuple(result['Customer_Id'])
a[:5]
# Out:
# ('1127684', '1127547', '1128241', '1128145', '1128222')

# %%
d = '2024-11-14'   ### Need to change this to D-1 everytime we run this code ###
# Get the current date
current_date = pd.Timestamp.now().date()
d_minus_1_days = current_date - pd.DateOffset(days=1)

# # Calculate D-60 days
# d_minus_60_days = '2024-07-17'
# # Calculate D-180 days
# d_minus_180_days = '2024-03-19'

# Calculate D-60 days
d_minus_60_days = d_minus_1_days - pd.DateOffset(days=60)
# Calculate D-180 days
d_minus_180_days = d_minus_1_days - pd.DateOffset(days=180)

print("D-1 day from current date", d_minus_1_days )
# print("D-60 day from the current date - 1:", d_minus_60_days)
# print("D-180 day from the current date -1:", d_minus_180_days)

d_minus_1_days_string = d_minus_1_days.strftime('%Y-%m-%d')
print("D-1 day from the current date:", d_minus_1_days_string)

d_minus_60_days_string = d_minus_60_days
print("D-60 day from the current date:", d_minus_60_days_string)

d_minus_180_days_string = d_minus_180_days
print("D-180 day from the current date:", d_minus_180_days_string)
# Out:
# D-1 day from current date 2024-11-14 00:00:00
# D-1 day from the current date: 2024-11-14
# D-60 day from the current date: 2024-09-15 00:00:00
# D-180 day from the current date: 2024-05-18 00:00:00

# %%
d = '2024-11-14'   ### Need to change this to D-1 everytime we run this code ###
# Get the current date
current_date = pd.Timestamp.now().date()
d_minus_1_days = current_date - pd.DateOffset(days=1)
# Calculate D-60 days
d_minus_60_days = d_minus_1_days - pd.DateOffset(days=60)
# Calculate D-180 days
d_minus_180_days = d_minus_1_days - pd.DateOffset(days=180)

print("D-1 day from current date", d_minus_1_days )
print("D-60 day from the current date - 1:", d_minus_60_days)
print("D-180 day from the current date -1:", d_minus_180_days)

d_minus_1_days_string = d_minus_1_days.strftime('%Y-%m-%d')
print("D-1 day from the current date:", d_minus_1_days_string)

d_minus_60_days_string = d_minus_60_days.strftime('%Y-%m-%d')
print("D-60 day from the current date:", d_minus_60_days_string)

d_minus_180_days_string = d_minus_180_days.strftime('%Y-%m-%d')
print("D-180 day from the current date:", d_minus_180_days_string)
# Out:
# D-1 day from current date 2024-11-14 00:00:00
# D-60 day from the current date - 1: 2024-09-15 00:00:00
# D-180 day from the current date -1: 2024-05-18 00:00:00
# D-1 day from the current date: 2024-11-14
# D-60 day from the current date: 2024-09-15
# D-180 day from the current date: 2024-05-18

# %% [markdown]
# The date should be D-1? If the date is not D-1 then ask Bala to refresh the table.

# %% [markdown]
# Step1: At line 11 change the date to D-1<br><br>
# Step2: At line around 36 (and (TSA_Opening_date < date '2023-10-18')   ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)) Change the date D-60 Days <br><br>
# Step3: At line around 45 (WHEN tsa_status = 'Active' and Last_TSA_EOD_Balance_Date is null and (TSA_Opening_date < date '2023-10-18')  ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)) Change the date D-60 Days <br><br>
# Step4: At line 58 (and TSA_Opening_date < date '2023-06-18'  and (Last_TSA_Credit_Date < date '2023-06-18' and Last_TSA_Debit_Date < date '2023-06-18' and coalesce(Last_Group_Stash_Credit_Date,date '1970-01-01') < date '2023-06-18')  ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)) <br><br>
# Step5: At line 72 (Run_Date = date '2024-01-09'###DATE change here to D-1) Change the date to D-1<br><br>

# %% [markdown]
# First Notification we change all the steps <br><br>
# Second and Third Notification we only change Step1 and Step5
# For Second Notificaiton and Third Notificaiton the customre id should be from the file sent by Marvin. <br><br>

# %%
sq = f"""
with
w_kyc
as
(
  select distinct PARTYID, SEGCATEGORYDESC, row_number() over(partition by partyid order by SEGEFFECTIVEFROM desc) as rnk from `core_raw.party_details`
),
w_tsa
as
(
  select * from risk_credit_mis.tsa_account_closure where Run_Date = date '{d_minus_1_days_string}' ###DATE change here to D-1
  and
  Customer_Id not in (select cast(PARTYID as string) from w_kyc where rnk = 1 and SEGCATEGORYDESC = 'BKYC')
  and
  --customer_id in (select cast(customer_id as string) from prj-prod-dataplatform.dap_ds_poweruser_playground.tsa_2nd_notification_base_10jan2024)
  customer_id in {a}
)
select * from w_tsa;
"""

dfd = client.query(sq).to_dataframe(progress_bar_type='tqdm')
dfd.shape
# Out:
# Job ID 60c6540e-5260-4e1b-b58f-a2d062468a01 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# (61629, 29)

# %%
sq = f"""
with
w_kyc
as
(
  select distinct PARTYID, SEGCATEGORYDESC, row_number() over(partition by partyid order by SEGEFFECTIVEFROM desc) as rnk from `core_raw.party_details`
),
w_tsa
as
(
  select * from risk_credit_mis.tsa_account_closure where Run_Date = date '{d_minus_1_days_string}'  ###DATE change here to D-1
  and
  Customer_Id not in (select cast(PARTYID as string) from w_kyc where rnk = 1 and SEGCATEGORYDESC = 'BKYC')
  and
  --customer_id in (select cast(customer_id as string) from prj-prod-dataplatform.dap_ds_poweruser_playground.tsa_2nd_notification_base_10jan2024)
  customer_id in {a}
),
w_approved
as
(
  select DISTINCT customerId from risk_credit_mis.loan_master_table where loantype = 'BIGLOAN' OR FLAGAPPROVAL = 1 OR FLAGDISBURSEMENT = 1  
  or (stage1Status = 'EXPIRED' AND cddInitiatedDateAndTime IS NULL)
)
select *
from
(
  select distinct
  a.Customer_Id,a.TSA_Opening_date,
  c.OFSTANDARDACCOUNTID as TSA_Account_Number, c.OfblockAmount, 
  a.TSA_Status,a.TSA_Balance,a.Solo_Stash_Balance,a.Group_Stash_Balance,a.Term_Deposit_Balance,a.Active_Term_Deposit_flag,a.Last_TSA_Credit_Date,a.Last_TSA_Debit_Date,
  a.ARI_Flag,a.Active_Loan,a.Total_Loan_Outstanding,  case when b.customerId is not null then 1 else 0 end as Approved_Loans,
  a.Pending_Loan_Applications,a.Hard_Reject_Loans_App,a.Soft_Reject_Loans_App,a.Cancelled_Loans_App, extract(date from a.Last_Login_Date) as Last_Login_Date,
  a.Last_TSA_EOD_Balance_Date,a.Last_Group_Stash_Credit_Date,a.Group_Stash_Balance_Owner,a.Run_Date,a.Batch,a.Processing_Month,a.pending_loans_not_expired_not_exempt,a.expired_loans,
  a.pending_loans_lastDt,a.expired_loans_lastDt,
  CASE 
    WHEN tsa_status = 'Active' and (Last_TSA_Credit_Date = date '1970-01-01' and Last_Group_Stash_Credit_Date is null)
    and (TSA_Opening_date < date '{d_minus_60_days_string}')   ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
    --and ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) = 0 )
    and (coalesce(Active_Loan,0) = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
    and (Active_Term_Deposit_flag = 0)
    and (ARI_Flag = 'N')
    --and (Approved_Loans = 0)  THEN 'TYPE 1'
    and b.customerId is null  THEN 'TYPE 1'


    WHEN tsa_status = 'Active' and Last_TSA_EOD_Balance_Date is null and (TSA_Opening_date < date '{d_minus_60_days_string}')  ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
    --and ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) = 0 )
    and (coalesce(Active_Loan,0) = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
    and (Active_Term_Deposit_flag = 0)
    and (ARI_Flag = 'N')
    --and (Approved_Loans = 0)
    and b.customerId is null  
    and (date_trunc(TSA_Opening_date,day) = date_trunc(Last_Login_Date,day)) THEN 'TYPE 2'

    
    WHEN 
    --( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) < 1 )
            --and 
            (coalesce(Active_Loan,0) = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
            and (Active_Term_Deposit_flag = 0)
            and TSA_Opening_date < date '{d_minus_180_days_string}'                                     ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
            and (Last_TSA_Credit_Date < date '{d_minus_180_days_string}'                                 ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
            and Last_TSA_Debit_Date < date '{d_minus_180_days_string}'                                         ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
            and coalesce(Last_Group_Stash_Credit_Date,date '1970-01-01') < date '{d_minus_180_days_string}' )  ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
            and tsa_status = 'Active'
            and (ARI_Flag = 'N')
    --and (Approved_Loans = 0)
            and b.customerId is null  
    THEN 'TYPE 3'
    ELSE 'NO ACTION'
    END AS ACTION_TYPE
  from w_tsa A
  left join w_approved b
  on cast(a.Customer_Id as int64) = b.customerId
  left join core_raw.customer_accounts c
  on c.OFCUSTOMERID = a.Customer_Id and c.CRINTERDESC = 'Transactional Savings Account Inv_R' and c.OFISCLOSED = 'N'
  where
  Run_Date = date '{d_minus_1_days_string}'  ###DATE change here to D-1
)
"""

# %%
print(sq)
# Out:
# with
# w_kyc
# as
# (
#   select distinct PARTYID, SEGCATEGORYDESC, row_number() over(partition by partyid order by SEGEFFECTIVEFROM desc) as rnk from `core_raw.party_details`
# ),
# w_tsa
# as
# (
#   select * from risk_credit_mis.tsa_account_closure where Run_Date = date '2024-11-14'  ###DATE change here to D-1
#   and
#   Customer_Id not in (select cast(PARTYID as string) from w_kyc where rnk = 1 and SEGCATEGORYDESC = 'BKYC')
#   and
#   --customer_id in (select cast(customer_id as string) from prj-prod-dataplatform.dap_ds_poweruser_playground.tsa_2nd_notification_base_10jan2024)
#   customer_id in ('1127684', '1127547', '1128241', '1128145', '1128222', '1128215', '1127495', '1128293', '1127864', '1128054', '1127961', '1498185', '1496766', '1497403', '1497137', '1496294', '1497703', '1498347', '1495921', '1498158', '1497367', '1498223', '1497678', '1498433', '1497043', '1497786', '1496221', '1498677', '1498423', '1498062', '1498666', '1497318', '1496876', '1497180', '1495901', '1497336', '1498207', '1498206', '1497856', '1495916', '1496551', '1497402', '1498518', '1497433', '1498445', '1497019', '1498191', '1497572', '1496057', '1497320', '1496049', '1497359', '1085372', '1129135', '1129187', '1501506', '1501333', '1500753', '1500321', '1500955', '1500012', '1500414', '1499220', '1500010', '1501591', '1500408', '1500740', '1499657', '1500934', '1501476', '1500370', '1500132', '1500840', '1501335', '1500850', '1500687', '1499347', '1499327', '1501446', '1501109', '1501594', '1500394', '1501550', '1500507', '1500420', '1500513', '1500266', '1501049', '1500238', '1500165', '1501549', '1499401', '1498982', '1500705', '1501081', '1499442', '1501043', '1501495', '1499473', '1498931', '1498813', '1498765', '1499194', '1501602', '1501224', '1499682', '1500066', '1130179', '1130222', '1130605', '1129416', '1129719', '1130211', '1130138', '1129806', '1130530', '1129399', '1504516', '1504656', '1503082', '1504121', '1503864', '1501709', '1504571', '1502457', '1502810', '1502690', '1503689', '1502670', '1502209', '1504346', '1503629', '1502367', '1501850', '1504129', '1503323', '1503072', '1502382', '1503832', '1504254', '1502440', '1502084', '1504310', '1502985', '1504136', '1504080', '1503275', '1504275', '1504296', '1502901', '1503994', '1503476', '1503051', '1503253', '1503073', '1501873', '1503959', '1503544', '1503297', '1131626', '1130720', '1130634', '1130729', '1505226', '1507082', '1506177', '1505750', '1506165', '1507192', '1507147', '1506084', '1505438', '1505193', '1506050', '1507435', '1506590', '1505783', '1506731', '1507724', '1507249', '1506955', '1504825', '1505412', '1506255', '1507282', '1505240', '1505929', '1507100', '1507005', '1507564', '1507426', '1506734', '1504971', '1505619', '1507622', '1505883', '1507250', '1505754', '1504937', '1506407', '1507751', '1506677', '1505900', '1506048', '1506281', '1506156', '1504947', '1506808', '1506684', '1504747', '1507077', '1507032', '1507159', '1507582', '1505067', '1038132', '1132406', '1132275', '1132129', '1132351', '1131993', '1131824', '1131939', '1131776', '1132071', '1509764', '1510070', '1509805', '1510102', '1509586', '1510339', '1509975', '1510190', '1510704', '1509114', '1508859', '1510904', '1510217', '1509956', '1510995', '1508715', '1511036', '1509690', '1511269', '1508498', '1508061', '1511335', '1509810', '1511592', '1509006', '1508038', '1511401', '1510728', '1509431', '1510747', '1509645', '1510831', '1508630', '1511160', '1508526', '1510249', '1509516', '1510152', '1510446', '1511520', '1510422', '1510581', '1509555', '1509813', '1508512', '1511551', '1511282', '1511423', '1509827', '1510623', '1511013', '1510653', '1509252', '1511230', '1508393', '1509227', '1509993', '1508364', '1510779', '1509524', '1509682', '1510714', '1509437', '1509575', '1511477', '1509348', '1511577', '1508246', '1509951', '1509127', '1511336', '1510191', '1510474', '1510985', '1508251', '1507897', '1510203', '1507878', '1510303', '1510166', '1133961', '1133522', '1133828', '1133643', '1134063', '1133728', '1133481', '1133499', '1133607', '1134266', '1133204', '1133129', '1133932', '1133092', '1133637', '1133301', '1133876', '1513121', '1512639', '1511799', '1513427', '1512845', '1511634', '1513518', '1512020', '1513658', '1512531', '1512204', '1512630', '1512933', '1513926', '1513576', '1513264', '1511686', '1512505', '1512557', '1514327', '1512062', '1512652', '1512765', '1514267', '1514172', '1511837', '1513901', '1514077', '1513088', '1513423', '1513031', '1513880', '1512419', '1513275', '1513989', '1513645', '1512469', '1513138', '1513539', '1513372',  ...
# ),
# w_approved
# as
# (
#   select DISTINCT customerId from risk_credit_mis.loan_master_table where loantype = 'BIGLOAN' OR FLAGAPPROVAL = 1 OR FLAGDISBURSEMENT = 1
#   or (stage1Status = 'EXPIRED' AND cddInitiatedDateAndTime IS NULL)
# )
# select *
# from
# (
#   select distinct
#   a.Customer_Id,a.TSA_Opening_date,
#   c.OFSTANDARDACCOUNTID as TSA_Account_Number, c.OfblockAmount,
#   a.TSA_Status,a.TSA_Balance,a.Solo_Stash_Balance,a.Group_Stash_Balance,a.Term_Deposit_Balance,a.Active_Term_Deposit_flag,a.Last_TSA_Credit_Date,a.Last_TSA_Debit_Date,
#   a.ARI_Flag,a.Active_Loan,a.Total_Loan_Outstanding,  case when b.customerId is not null then 1 else 0 end as Approved_Loans,
#   a.Pending_Loan_Applications,a.Hard_Reject_Loans_App,a.Soft_Reject_Loans_App,a.Cancelled_Loans_App, extract(date from a.Last_Login_Date) as Last_Login_Date,
#   a.Last_TSA_EOD_Balance_Date,a.Last_Group_Stash_Credit_Date,a.Group_Stash_Balance_Owner,a.Run_Date,a.Batch,a.Processing_Month,a.pending_loans_not_expired_not_exempt,a.expired_loans,
#   a.pending_loans_lastDt,a.expired_loans_lastDt,
#   CASE
#     WHEN tsa_status = 'Active' and (Last_TSA_Credit_Date = date '1970-01-01' and Last_Group_Stash_Credit_Date is null)
#     and (TSA_Opening_date < date '2024-09-15')   ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#     --and ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) = 0 )
#     and (coalesce(Active_Loan,0) = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
#     and (Active_Term_Deposit_flag = 0)
#     and (ARI_Flag = 'N')
#     --and (Approved_Loans = 0)  THEN 'TYPE 1'
#     and b.customerId is null  THEN 'TYPE 1'
#
#
#     WHEN tsa_status = 'Active' and Last_TSA_EOD_Balance_Date is null and (TSA_Opening_date < date '2024-09-15')  ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#     --and ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) = 0 )
#     and (coalesce(Active_Loan,0) = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
#     and (Active_Term_Deposit_flag = 0)
#     and (ARI_Flag = 'N')
#     --and (Approved_Loans = 0)
#     and b.customerId is null
#     and (date_trunc(TSA_Opening_date,day) = date_trunc(Last_Login_Date,day)) THEN 'TYPE 2'
#
#
#     WHEN
#     --( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) < 1 )
#             --and
#             (coalesce(Active_Loan,0) = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
#             and (Active_Term_Deposit_flag = 0)
#             and TSA_Opening_date < date '2024-05-18'                                     ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#             and (Last_TSA_Credit_Date < date '2024-05-18'                                 ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#             and Last_TSA_Debit_Date < date '2024-05-18'                                         ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#             and coalesce(Last_Group_Stash_Credit_Date,date '1970-01-01') < date '2024-05-18' )  ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#             and tsa_status = 'Active'
#             and (ARI_Flag = 'N')
#     --and (Approved_Loans = 0)
#             and b.customerId is null
#     THEN 'TYPE 3'
#     ELSE 'NO ACTION'
#     END AS ACTION_TYPE
#   from w_tsa A
#   left join w_approved b
#   on cast(a.Customer_Id as int64) = b.customerId
#   left join core_raw.customer_accounts c
#   on c.OFCUSTOMERID = a.Customer_Id and c.CRINTERDESC = 'Transactional Savings Account Inv_R' and c.OFISCLOSED = 'N'
#   where
#   Run_Date = date '2024-11-14'  ###DATE change here to D-1
# )

# %%
df = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')
# Out:
# Job ID 954e425d-a518-4803-9ffd-8c390711c453 successfully executed: |          |
# Downloading: 100%|██████████|

# %%
pd.set_option('display.max_columns', None)
df.sample(10)
# Out:
#       Customer_Id TSA_Opening_date TSA_Account_Number  OfblockAmount  \
# 11744     1584291       2022-08-29     60815842910002            0.0
# 28764     1459042       2022-07-11     60814590420006            0.0
# 29529     1440352       2022-07-03     60814403520006            0.0
# 19645     1489673       2022-07-25     60814896730006            0.0
# 26419     1588106       2022-08-31     60815881060002            0.0
# 27100     1373220       2022-05-13     60813732200006            0.0
# 26811     1611482       2022-09-10     60816114820006            0.0
# 55562     1362172       2022-05-04     60813621720006            0.0
# 10480     1421899       2022-06-24     60814218990001            0.0
# 30750     1194863       2022-01-03     60811948630007            0.0
#
#       TSA_Status  TSA_Balance  Solo_Stash_Balance  Group_Stash_Balance  \
# 11744     Active          0.0                 0.0                  0.0
# 28764     Active          0.0                 0.0                  0.0
# 29529     Active          0.0                 0.0                  0.0
# 19645     Active          0.0                 0.0                  0.0
# 26419     Active          0.0                 0.0                  0.0
# 27100     Active          0.0                 0.0                  0.0
# 26811     Active          0.0                 0.0                  0.0
# 55562     Active          0.0                 0.0                  0.0
# 10480     Active          0.0                 0.0                  0.0
# 30750     Active          0.0                 0.0                  0.0
#
#        Term_Deposit_Balance  Active_Term_Deposit_flag Last_TSA_Credit_Date  \
# 11744                   0.0                         0           1970-01-01
# 28764                   0.0                         0           1970-01-01
# 29529                   0.0                         0           1970-01-01
# 19645                   0.0                         0           1970-01-01
# 26419                   0.0                         0           1970-01-01
# 27100                   0.0                         0           1970-01-01
# 26811                   0.0                         0           1970-01-01
# 55562                   0.0                         0           1970-01-01
# 10480                   0.0                         0           1970-01-01
# 30750                   0.0                         0           1970-01-01
#
#       Last_TSA_Debit_Date ARI_Flag  Active_Loan  Total_Loan_Outstanding  \
# 11744          1970-01-01        N            0                     0.0
# 28764          1970-01-01        N            0                     0.0
# 29529          1970-01-01        N            0                     0.0
# 19645          1970-01-01        N            0                     0.0
# 26419          1970-01-01        Y            0                     0.0
# 27100          1970-01-01        N            0                     0.0
# 26811          1970-01-01        N            0                     0.0
# 55562          1970-01-01        N            0                     0.0
# 10480          1970-01-01        Y            0                     0.0
# 30750          1970-01-01        N            0                     0.0
#
#        Approved_Loans  Pending_Loan_Applications  Hard_Reject_Loans_App  \
# 11744               0                          1                      0
# 28764               0                          1                      0
# 29529               0                          1                      0
# 19645               0                          1                      0
# 26419               0                          0                      0
# 27100               0                          3                      0
# 26811               0                          1                      0
# 55562               0                          1                      1
# 10480               0                          0                      0
# 30750               0                          2                      0
#
#        Soft_Reject_Loans_App  Cancelled_Loans_App Last_Login_Date  \
# 11744                      0                    0      2022-08-29
# 28764                      0                    0      2022-07-11
# 29529                      1                    0      2022-08-12
# 19645                      0                    0      2022-08-27
# 26419                      0                    0      2022-08-31
# 27100                      0                    0      2023-04-10
# 26811                      0                    0      2022-09-10
# 55562                      0                    0      2024-03-27
# 10480                      1                    0      2024-07-21
# 30750                      0                    0      2024-05-16
#
#       Last_TSA_EOD_Balance_Date Last_Group_Stash_Credit_Date  \
# 11744                       NaT                          NaT
# 28764                       NaT                          NaT
# 29529                       NaT                          NaT
# 19645                       NaT                          NaT
# 26419                       NaT                          NaT
# 27100                       NaT                          NaT
# 26811                       NaT                          NaT
# 55562                       NaT                          NaT
# 10480                       NaT                          NaT
# 30750                       NaT                          NaT
#
#        Group_Stash_Balance_Owner    Run_Date    Batch Processing_Month  \
# 11744                        NaN  2024-11-14  Batch_1         November
# 28764                        NaN  2024-11-14  Batch_1         November
# 29529                        NaN  2024-11-14  Batch_1         November
# 19645                        NaN  2024-11-14  Batch_1         November
# 26419                        NaN  2024-11-14  Batch_1         November
# 27100                        NaN  2024-11-14  Batch_1         November
# 26811                        NaN  2024-11-14  Batch_1         November
# 55562                        NaN  2024-11-14  Batch_1         November
# 10480                        NaN  2024-11-14  Batch_1         November
# 30750                        NaN  2024-11-14  Batch_1         November
#
#        pending_loans_not_expired_not_exempt  expired_loans  \
# 11744                                     0              0
# 28764                                     0              0
# 29529                                     1              0
# 19645                                     1              1
# 26419                                     0              1
# 27100                                     3              1
# 26811                                     1              0
# 55562                                     0              0
# 10480                                     0              0
# 30750                                     2              0
#
#       pending_loans_lastDt expired_loans_lastDt ACTION_TYPE
# 11744                  NaT                  NaT   NO ACTION
# 28764                  NaT                  NaT   NO ACTION
# 29529           2022-08-03                  NaT   NO ACTION
# 19645           2022-08-24           2022-11-26   NO ACTION
# 26419                  NaT           2022-11-30   NO ACTION
# 27100           2023-05-01           2023-03-21   NO ACTION
# 26811           2022-10-11                  NaT   NO ACTION
# 55562                  NaT                  NaT   NO ACTION
# 10480                  NaT                  NaT   NO ACTION
# 30750           2024-06-15                  NaT   NO ACTION

# %%
df.shape
# Out:
# (61629, 32)

# %%
df['ACTION_TYPE'].value_counts()
# Out:
# ACTION_TYPE
# NO ACTION    61609
# TYPE 1          18
# TYPE 3           1
# TYPE 2           1
# Name: count, dtype: int64

# %%
df.to_excel(r"C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Marvin\TSA Account Closure\November2024\SecondNotification_files\20241115_TSA_Account_Closure_2ndtNotification.xlsx", sheet_name='TSA_Closure_2ndNotification', index = False)
