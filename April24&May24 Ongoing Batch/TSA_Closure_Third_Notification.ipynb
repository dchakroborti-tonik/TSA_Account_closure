# %% [markdown]
# # <div align="center" style="color: #ff5733;">TSA Closure Third Notification</div>

# %%
# Import Libraries   

import pandas as pd  
import numpy as np  

from google.cloud import bigquery
import os

path = r"C:\Users\DwaipayanChakroborti\AppData\Roaming\gcloud\legacy_credentials\dchakroborti@tonikbank.com\adc.json"

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = path
client = bigquery.Client(project="prj-prod-dataplatform")

# %% [markdown]
# # Ask Balasubramani to refresh risk_credit_mis.tsa_account_closure table.
# **Check if that is refreshed when Balasubramani confirms it**

# %%
sq = """select Run_Date, count(1)cnt from risk_credit_mis.tsa_account_closure group by 1 order by 1 desc"""
df = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')
df.head(1)
# Out:
# Job ID 4fa945a9-6b28-4076-a175-7dae51ab377b successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
#      Run_Date     cnt
# 0  2024-06-25  587056

# %% [markdown]
# The date should show yesterday's date

# %% [markdown]
# # Read the data from the first sheet for Type1 and Type2 data provided by Marvin

# %%
d1 = pd.read_excel(r"C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Marvin\TSA Account Closure\April24&May24 Ongoing Batch\ThirdNotification_files\Type 1  & 2.xlsx")
d1.shape
# Out:
# (8199, 2)

# %%
print(f"The unique count of customer_id is:\t{len(d1['Customer_Id'].unique())}")
d1.head()
# Out:
# The unique count of customer_id is:	8197
#    Customer_Id ACTION_TYPE
# 0      2266216      TYPE 1
# 1      2436527      TYPE 1
# 2      2410040      TYPE 1
# 3      2435015      TYPE 1
# 4      2369628      TYPE 1

# %% [markdown]
# # Read the data from the second sheet for Type3 data provided by Marvin

# %%
d2 = pd.read_excel(r"C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Marvin\TSA Account Closure\April24&May24 Ongoing Batch\ThirdNotification_files\Type 3.xlsx")
d2.shape
# Out:
# (975, 2)

# %%
print(f"The unique count of customer_id is:\t{len(d2['Customer_Id'].unique())}")
d2.head()
# Out:
# The unique count of customer_id is:	975
#    Customer_Id ACTION_TYPE
# 0      1026257      TYPE 3
# 1      2232744      TYPE 3
# 2      1848755      TYPE 3
# 3      2266061      TYPE 3
# 4      2131056      TYPE 3

# %%
result = pd.concat([d1, d2], axis=0, ignore_index=True)
result.shape
# Out:
# (9174, 2)

# %%
result.ACTION_TYPE.value_counts()
# Out:
# ACTION_TYPE
# TYPE 1    8172
# TYPE 3     975
# TYPE 2      27
# Name: count, dtype: int64

# %%
result[result['Customer_Id'] == '2256481']
# Out:
#      Customer_Id ACTION_TYPE
# 8820     2256481      TYPE 3

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9174 entries, 0 to 9173
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer_Id  9174 non-null   object
#  1   ACTION_TYPE  9174 non-null   object
# dtypes: object(2)
# memory usage: 143.5+ KB

# %%
result['Customer_Id'] = result['Customer_Id'].astype(str)
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9174 entries, 0 to 9173
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer_Id  9174 non-null   object
#  1   ACTION_TYPE  9174 non-null   object
# dtypes: object(2)
# memory usage: 143.5+ KB

# %%
result.to_csv("temp.csv", index = False)

# %%
a = tuple(result['Customer_Id'])
a[:5]
# Out:
# ('2266216', '2436527', '2410040', '2435015', '2369628')

# %%
d = '2024-06-25'   ### Need to change this to D-1 everytime we run this code ###
# Get the current date
current_date = pd.Timestamp.now().date()
d_minus_1_days = current_date - pd.DateOffset(days=1)
# Calculate D-60 days
d_minus_60_days = '2024-03-27'
# Calculate D-180 days
d_minus_180_days = '2023-11-28'

print("D-1 day from current date", d_minus_1_days )
print("D-60 day from the current date - 1:", d_minus_60_days)
print("D-180 day from the current date -1:", d_minus_180_days)

d_minus_1_days_string = d_minus_1_days.strftime('%Y-%m-%d')
print("D-1 day from the current date:", d_minus_1_days_string)

d_minus_60_days_string = d_minus_60_days
print("D-60 day from the current date:", d_minus_60_days_string)

d_minus_180_days_string = d_minus_180_days
print("D-180 day from the current date:", d_minus_180_days_string)
# Out:
# D-1 day from current date 2024-06-25 00:00:00
# D-60 day from the current date - 1: 2024-03-27
# D-180 day from the current date -1: 2023-11-28
# D-1 day from the current date: 2024-06-25
# D-60 day from the current date: 2024-03-27
# D-180 day from the current date: 2023-11-28

# %% [markdown]
# Step1: At line 11 change the date to D-1<br><br>
# Step2: At line around 36 (and (TSA_Opening_date < date '2023-10-18')   ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)) Change the date D-60 Days <br><br>
# Step3: At line around 45 (WHEN tsa_status = 'Active' and Last_TSA_EOD_Balance_Date is null and (TSA_Opening_date < date '2023-10-18')  ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)) Change the date D-60 Days <br><br>
# Step4: At line 58 (and TSA_Opening_date < date '2023-06-18'  and (Last_TSA_Credit_Date < date '2023-06-18' and Last_TSA_Debit_Date < date '2023-06-18' and coalesce(Last_Group_Stash_Credit_Date,date '1970-01-01') < date '2023-06-18')  ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)) <br><br>
# Step5: At line 72 (Run_Date = date '2024-01-09'###DATE change here to D-1) Change the date to D-1<br><br>

# %% [markdown]
# First Notification we change all the steps <br><br>
# Second and Third Notification we only change Step1 and Step5
# For Second Notificaiton and Third Notificaiton the customre id should be from the file sent by Marvin. <br><br>

# %%
sq = f"""
with
w_kyc
as
(
  select distinct PARTYID, SEGCATEGORYDESC, row_number() over(partition by partyid order by SEGEFFECTIVEFROM desc) as rnk from `core_raw.party_details`
),
w_tsa
as
(
  select * from risk_credit_mis.tsa_account_closure where Run_Date = date '{d_minus_1_days_string}' ###DATE change here to D-1
  and
  Customer_Id not in (select cast(PARTYID as string) from w_kyc where rnk = 1 and SEGCATEGORYDESC = 'BKYC')
  and
  --customer_id in (select cast(customer_id as string) from prj-prod-dataplatform.dap_ds_poweruser_playground.tsa_2nd_notification_base_10jan2024)
  customer_id in {a}
)
select * from w_tsa;
"""

dfd = client.query(sq).to_dataframe()
dfd.shape
# Out:
# (9173, 29)

# %%
sq = f"""
with
w_kyc
as
(
  select distinct PARTYID, SEGCATEGORYDESC, row_number() over(partition by partyid order by SEGEFFECTIVEFROM desc) as rnk from `core_raw.party_details`
),
w_tsa
as
(
  select * from risk_credit_mis.tsa_account_closure where Run_Date = date '{d_minus_1_days_string}'  ###DATE change here to D-1
  and
  Customer_Id not in (select cast(PARTYID as string) from w_kyc where rnk = 1 and SEGCATEGORYDESC = 'BKYC')
  and
  --customer_id in (select cast(customer_id as string) from prj-prod-dataplatform.dap_ds_poweruser_playground.tsa_2nd_notification_base_10jan2024)
  customer_id in {a}
),
w_approved
as
(
  select DISTINCT customerId from risk_credit_mis.loan_master_table where loantype = 'BIGLOAN' OR FLAGAPPROVAL = 1 OR FLAGDISBURSEMENT = 1  
  or (stage1Status = 'EXPIRED' AND cddInitiatedDateAndTime IS NULL)
)
select *
from
(
  select distinct
  a.Customer_Id,a.TSA_Opening_date,
  c.OFSTANDARDACCOUNTID as TSA_Account_Number, c.OfblockAmount, 
  a.TSA_Status,a.TSA_Balance,a.Solo_Stash_Balance,a.Group_Stash_Balance,a.Term_Deposit_Balance,a.Active_Term_Deposit_flag,a.Last_TSA_Credit_Date,a.Last_TSA_Debit_Date,
  a.ARI_Flag,a.Active_Loan,a.Total_Loan_Outstanding,  case when b.customerId is not null then 1 else 0 end as Approved_Loans,
  a.Pending_Loan_Applications,a.Hard_Reject_Loans_App,a.Soft_Reject_Loans_App,a.Cancelled_Loans_App, extract(date from a.Last_Login_Date) as Last_Login_Date,
  a.Last_TSA_EOD_Balance_Date,a.Last_Group_Stash_Credit_Date,a.Group_Stash_Balance_Owner,a.Run_Date,a.Batch,a.Processing_Month,a.pending_loans_not_expired_not_exempt,a.expired_loans,
  a.pending_loans_lastDt,a.expired_loans_lastDt,
  CASE 
    WHEN tsa_status = 'Active' and (Last_TSA_Credit_Date = date '1970-01-01' and Last_Group_Stash_Credit_Date is null)
    and (TSA_Opening_date < date '{d_minus_60_days_string}')   ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
    and ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) = 0 )
    and (Active_Loan = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
    and (Active_Term_Deposit_flag = 0)
    and (ARI_Flag = 'N')
    --and (Approved_Loans = 0)  THEN 'TYPE 1'
    and b.customerId is null  THEN 'TYPE 1'


    WHEN tsa_status = 'Active' and Last_TSA_EOD_Balance_Date is null and (TSA_Opening_date < date '{d_minus_60_days_string}')  ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
    and ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) = 0 )
    and (Active_Loan = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
    and (Active_Term_Deposit_flag = 0)
    and (ARI_Flag = 'N')
    --and (Approved_Loans = 0)
    and b.customerId is null  
    and (date_trunc(TSA_Opening_date,day) = date_trunc(Last_Login_Date,day)) THEN 'TYPE 2'

    
    WHEN ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) < 1 )
            and (Active_Loan = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
            and (Active_Term_Deposit_flag = 0)
            and TSA_Opening_date < date '{d_minus_180_days_string}'                                     ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
            and (Last_TSA_Credit_Date < date '{d_minus_180_days_string}'                                 ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
            and Last_TSA_Debit_Date < date '{d_minus_180_days_string}'                                         ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
            and coalesce(Last_Group_Stash_Credit_Date,date '1970-01-01') < date '{d_minus_180_days_string}' )  ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
            and tsa_status = 'Active'
            and (ARI_Flag = 'N')
    --and (Approved_Loans = 0)
            and b.customerId is null  
    THEN 'TYPE 3'
    ELSE 'NO ACTION'
    END AS ACTION_TYPE
  from w_tsa A
  left join w_approved b
  on cast(a.Customer_Id as int64) = b.customerId
  left join core_raw.customer_accounts c
  on c.OFCUSTOMERID = a.Customer_Id and c.CRINTERDESC = 'Transactional Savings Account Inv_R' and c.OFISCLOSED = 'N'
  where
  Run_Date = date '{d_minus_1_days_string}'  ###DATE change here to D-1
)
"""

# %%
print(sq)
# Out:
# with
# w_kyc
# as
# (
#   select distinct PARTYID, SEGCATEGORYDESC, row_number() over(partition by partyid order by SEGEFFECTIVEFROM desc) as rnk from `core_raw.party_details`
# ),
# w_tsa
# as
# (
#   select * from risk_credit_mis.tsa_account_closure where Run_Date = date '2024-06-25'  ###DATE change here to D-1
#   and
#   Customer_Id not in (select cast(PARTYID as string) from w_kyc where rnk = 1 and SEGCATEGORYDESC = 'BKYC')
#   and
#   --customer_id in (select cast(customer_id as string) from prj-prod-dataplatform.dap_ds_poweruser_playground.tsa_2nd_notification_base_10jan2024)
#   customer_id in ('2266216', '2436527', '2410040', '2435015', '2369628', '2418818', '2438120', '2434093', '2437488', '2418528', '2214771', '2435353', '2415353', '2432817', '2132808', '2413654', '2421344', '2402517', '2425507', '2439432', '2422214', '2416497', '2395096', '2418328', '2434532', '2425812', '2435956', '2409738', '2415038', '2409491', '2421329', '2346034', '2418532', '2437285', '2436755', '2423971', '2364216', '2439110', '2131958', '2424262', '2417824', '2436469', '2289601', '2415484', '2420838', '2441989', '2427384', '2427678', '2411545', '2308820', '2435022', '2135646', '2415736', '2415024', '2358621', '2424531', '2436982', '2432435', '2420379', '2434586', '2430113', '2415597', '2436384', '2422738', '2433813', '2415056', '2422097', '2441800', '2439532', '2422372', '2434781', '2411910', '2441920', '2413757', '2429836', '2009692', '2417848', '2412126', '2419822', '2418103', '2416548', '2416326', '2404432', '2409074', '2441312', '2409449', '2424617', '2410106', '2416241', '2423485', '2410441', '2435979', '2412022', '2436877', '2411024', '2348360', '2430215', '2427563', '2440713', '2433975', '2420286', '2415755', '2427266', '2394698', '2408784', '1769393', '2438352', '2418730', '2410079', '2440203', '2420513', '2428348', '2428587', '2438635', '2405728', '2419441', '2425676', '2435814', '2430301', '2431058', '2419874', '1891253', '2420320', '2441925', '2411203', '2436943', '2413777', '2418135', '2440970', '2430969', '2440067', '2433009', '2426219', '2371936', '2437284', '2314418', '2428098', '2425146', '2439192', '2440270', '2423276', '2422406', '2441265', '2419819', '2420804', '2370176', '2439902', '2432747', '2411980', '2426479', '2422102', '2431844', '2435281', '2432795', '2440601', '2440892', '2432133', '2433261', '2413690', '2435026', '2416962', '2411292', '2415654', '2431647', '2410303', '2429593', '2427683', '2432630', '2428584', '2411759', '1983544', '2418363', '2412577', '2425335', '2413719', '2421269', '2436021', '2428449', '2423601', '2426087', '2409085', '2419361', '2408598', '2433841', '2432205', '1129079', '2430524', '2409300', '2410207', '2413900', '2420919', '2437822', '2409611', '2428544', '2413430', '2430464', '2396113', '2432389', '2416439', '2412216', '2440882', '2434358', '2437013', '2383463', '2420797', '2437654', '2419871', '2421251', '2410843', '2435050', '2419300', '2434860', '2422388', '2133314', '2436944', '2405432', '2419745', '2432145', '2416465', '2436741', '2423693', '2425553', '2413055', '2427787', '2415655', '2421093', '2415950', '2413463', '2289909', '2428679', '2440900', '2432667', '2419465', '2418597', '2157600', '2408907', '2426854', '2368972', '2437684', '2434072', '2441790', '2427555', '2129292', '2423204', '2426079', '2416319', '2434883', '2430823', '2362160', '2412087', '2436815', '2403678', '2417206', '2433794', '2412155', '2420186', '2210493', '2430917', '2431172', '2414528', '2434403', '2410538', '2414437', '2437349', '2429198', '2403272', '2414500', '2430576', '2438948', '2411199', '2424159', '2422949', '2410054', '2413919', '2415818', '2429047', '2409209', '2261989', '2426744', '2410148', '2417009', '2408691', '2413924', '2427085', '2427842', '2436767', '2428343', '2428120', '2439813', '2426117', '2418425', '2415249', '2421881', '2437427', '2417431', '2180940', '2440054', '2414240', '2424893', '2412085', '2415989', '2421715', '2426691', '2417285', '2416303', '2441554', '2416175', '2440969', '2441025', '2411905', '2360629', '2420882', '2424234', '2437418', '2416014', '2410285', '2414915', '2418571', '2440307', '2432085', '1366893', '2419346', '2298990', '2425130', '2418853', '2433759', '2439623', '2422817', '2436786', '2438877', '2416276', '2430712', '2438619', '2431210', '2410346', '2436507', '2431294', '2436342', '2414735', '2410605', '2411865', '2423475', '2416265', '2422299', '2426126', '2410867', '2436413', '2431289', '2415815', '2418909', '2410536', '2411779', '2409716', '2439009', '2438675', '2431548', '2413414', '2438796', '2436343', '2417761', '2414570', '2436517',  ...
# ),
# w_approved
# as
# (
#   select DISTINCT customerId from risk_credit_mis.loan_master_table where loantype = 'BIGLOAN' OR FLAGAPPROVAL = 1 OR FLAGDISBURSEMENT = 1
#   or (stage1Status = 'EXPIRED' AND cddInitiatedDateAndTime IS NULL)
# )
# select *
# from
# (
#   select distinct
#   a.Customer_Id,a.TSA_Opening_date,
#   c.OFSTANDARDACCOUNTID as TSA_Account_Number, c.OfblockAmount,
#   a.TSA_Status,a.TSA_Balance,a.Solo_Stash_Balance,a.Group_Stash_Balance,a.Term_Deposit_Balance,a.Active_Term_Deposit_flag,a.Last_TSA_Credit_Date,a.Last_TSA_Debit_Date,
#   a.ARI_Flag,a.Active_Loan,a.Total_Loan_Outstanding,  case when b.customerId is not null then 1 else 0 end as Approved_Loans,
#   a.Pending_Loan_Applications,a.Hard_Reject_Loans_App,a.Soft_Reject_Loans_App,a.Cancelled_Loans_App, extract(date from a.Last_Login_Date) as Last_Login_Date,
#   a.Last_TSA_EOD_Balance_Date,a.Last_Group_Stash_Credit_Date,a.Group_Stash_Balance_Owner,a.Run_Date,a.Batch,a.Processing_Month,a.pending_loans_not_expired_not_exempt,a.expired_loans,
#   a.pending_loans_lastDt,a.expired_loans_lastDt,
#   CASE
#     WHEN tsa_status = 'Active' and (Last_TSA_Credit_Date = date '1970-01-01' and Last_Group_Stash_Credit_Date is null)
#     and (TSA_Opening_date < date '2024-03-27')   ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#     and ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) = 0 )
#     and (Active_Loan = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
#     and (Active_Term_Deposit_flag = 0)
#     and (ARI_Flag = 'N')
#     --and (Approved_Loans = 0)  THEN 'TYPE 1'
#     and b.customerId is null  THEN 'TYPE 1'
#
#
#     WHEN tsa_status = 'Active' and Last_TSA_EOD_Balance_Date is null and (TSA_Opening_date < date '2024-03-27')  ####D-60 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#     and ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) = 0 )
#     and (Active_Loan = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
#     and (Active_Term_Deposit_flag = 0)
#     and (ARI_Flag = 'N')
#     --and (Approved_Loans = 0)
#     and b.customerId is null
#     and (date_trunc(TSA_Opening_date,day) = date_trunc(Last_Login_Date,day)) THEN 'TYPE 2'
#
#
#     WHEN ( round(coalesce(TSA_Balance,0) + coalesce(Solo_Stash_Balance,0) + coalesce(Group_Stash_Balance,0) + coalesce(Term_Deposit_Balance,0),2) < 1 )
#             and (Active_Loan = 0) and (COALESCE(Pending_Loan_Applications,0) = 0)
#             and (Active_Term_Deposit_flag = 0)
#             and TSA_Opening_date < date '2023-11-28'                                     ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#             and (Last_TSA_Credit_Date < date '2023-11-28'                                 ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#             and Last_TSA_Debit_Date < date '2023-11-28'                                         ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#             and coalesce(Last_Group_Stash_Credit_Date,date '1970-01-01') < date '2023-11-28' )  ####D-180 days(SHOULD BE SAME DATE FOR 1ST,2ND,3RD NOTIFICATION)
#             and tsa_status = 'Active'
#             and (ARI_Flag = 'N')
#     --and (Approved_Loans = 0)
#             and b.customerId is null
#     THEN 'TYPE 3'
#     ELSE 'NO ACTION'
#     END AS ACTION_TYPE
#   from w_tsa A
#   left join w_approved b
#   on cast(a.Customer_Id as int64) = b.customerId
#   left join core_raw.customer_accounts c
#   on c.OFCUSTOMERID = a.Customer_Id and c.CRINTERDESC = 'Transactional Savings Account Inv_R' and c.OFISCLOSED = 'N'
#   where
#   Run_Date = date '2024-06-25'  ###DATE change here to D-1
# )

# %%
df = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')
# Out:
# Job ID 80b67701-3e7a-479b-9a10-64168698b3a1 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|

# %%
pd.set_option('display.max_columns', None)
df.sample(10)
# Out:
#      Customer_Id TSA_Opening_date TSA_Account_Number  OfblockAmount  \
# 3234     2420651       2024-03-16     60824206510001            0.0
# 1881     2415975       2024-03-01     60824159750003            0.0
# 237      2417801       2024-03-03     60824178010001            0.0
# 4278     2220419       2023-09-03     60822204190003            0.0
# 7904     2437994       2024-03-23     60824379940004            0.0
# 4724     2323685       2024-03-21     60823236850007            0.0
# 3714     2438821       2024-03-24     60824388210008            0.0
# 6367     2411400       2024-02-25     60824114000003            0.0
# 3340     2412760       2024-02-27     60824127600008            0.0
# 5083     2420205       2024-03-05     60824202050003            0.0
#
#      TSA_Status  TSA_Balance  Solo_Stash_Balance  Group_Stash_Balance  \
# 3234     Active          0.0                 0.0                  0.0
# 1881     Active          0.0                 0.0                  0.0
# 237      Active          0.0                 0.0                  0.0
# 4278     Active          0.0                 0.0                  0.0
# 7904     Active          0.0                 0.0                  0.0
# 4724     Active          0.0                 0.0                  0.0
# 3714     Active          0.0                 0.0                  0.0
# 6367     Active          0.0                 0.0                  0.0
# 3340     Active          0.0                 0.0                  0.0
# 5083     Active          0.0                 0.0                  0.0
#
#       Term_Deposit_Balance  Active_Term_Deposit_flag Last_TSA_Credit_Date  \
# 3234                   0.0                         0           1970-01-01
# 1881                   0.0                         0           1970-01-01
# 237                    0.0                         0           1970-01-01
# 4278                   0.0                         0           2023-11-06
# 7904                   0.0                         0           1970-01-01
# 4724                   0.0                         0           1970-01-01
# 3714                   0.0                         0           1970-01-01
# 6367                   0.0                         0           1970-01-01
# 3340                   0.0                         0           1970-01-01
# 5083                   0.0                         0           1970-01-01
#
#      Last_TSA_Debit_Date ARI_Flag  Active_Loan  Total_Loan_Outstanding  \
# 3234          1970-01-01        N            0                     0.0
# 1881          1970-01-01        N            0                     0.0
# 237           1970-01-01        N            0                     0.0
# 4278          1970-01-01        N            0                     0.0
# 7904          1970-01-01        N            0                     0.0
# 4724          1970-01-01        N            0                     0.0
# 3714          1970-01-01        N            0                     0.0
# 6367          1970-01-01        N            0                     0.0
# 3340          1970-01-01        N            0                     0.0
# 5083          1970-01-01        N            0                     0.0
#
#       Approved_Loans  Pending_Loan_Applications  Hard_Reject_Loans_App  \
# 3234               0                          0                      0
# 1881               0                          0                      0
# 237                0                          0                      1
# 4278               0                          0                      1
# 7904               0                          0                      0
# 4724               0                          0                      0
# 3714               0                          0                      0
# 6367               0                          0                      0
# 3340               0                          0                      1
# 5083               0                          0                      0
#
#       Soft_Reject_Loans_App  Cancelled_Loans_App Last_Login_Date  \
# 3234                      0                    0      2024-03-16
# 1881                      0                    0      2024-03-13
# 237                       0                    0      2024-03-03
# 4278                      0                    0      2023-11-06
# 7904                      0                    0      2024-03-23
# 4724                      0                    0      2024-03-21
# 3714                      0                    0      2024-03-24
# 6367                      0                    0      2024-03-22
# 3340                      0                    0      2024-05-05
# 5083                      0                    0      2024-03-14
#
#      Last_TSA_EOD_Balance_Date Last_Group_Stash_Credit_Date  \
# 3234                       NaT                          NaT
# 1881                       NaT                          NaT
# 237                        NaT                          NaT
# 4278                       NaT                          NaT
# 7904                       NaT                          NaT
# 4724                       NaT                          NaT
# 3714                       NaT                          NaT
# 6367                       NaT                          NaT
# 3340                       NaT                          NaT
# 5083                       NaT                          NaT
#
#       Group_Stash_Balance_Owner    Run_Date    Batch Processing_Month  \
# 3234                        NaN  2024-06-25  Batch_1             June
# 1881                        NaN  2024-06-25  Batch_1             June
# 237                         NaN  2024-06-25  Batch_1             June
# 4278                        NaN  2024-06-25  Batch_1             June
# 7904                        NaN  2024-06-25  Batch_1             June
# 4724                        NaN  2024-06-25  Batch_1             June
# 3714                        NaN  2024-06-25  Batch_1             June
# 6367                        NaN  2024-06-25  Batch_1             June
# 3340                        NaN  2024-06-25  Batch_1             June
# 5083                        NaN  2024-06-25  Batch_1             June
#
#       pending_loans_not_expired_not_exempt  expired_loans  \
# 3234                                     0              1
# 1881                                     0              1
# 237                                      0              0
# 4278                                     0              0
# 7904                                     0              1
# 4724                                     0              2
# 3714                                     0              1
# 6367                                     0              1
# 3340                                     0              0
# 5083                                     0              1
#
#      pending_loans_lastDt expired_loans_lastDt ACTION_TYPE
# 3234                  NaT           2024-06-05      TYPE 1
# 1881                  NaT           2024-06-01      TYPE 1
# 237                   NaT                  NaT      TYPE 1
# 4278                  NaT                  NaT      TYPE 3
# 7904                  NaT           2024-06-22      TYPE 1
# 4724                  NaT           2024-06-20      TYPE 1
# 3714                  NaT           2024-06-22      TYPE 1
# 6367                  NaT           2024-05-26      TYPE 1
# 3340                  NaT                  NaT      TYPE 1
# 5083                  NaT           2024-06-04      TYPE 1

# %%
df.shape
# Out:
# (9173, 32)

# %%
df['ACTION_TYPE'].value_counts()
# Out:
# ACTION_TYPE
# TYPE 1       8107
# TYPE 3        951
# NO ACTION      90
# TYPE 2         25
# Name: count, dtype: int64

# %%
df.to_excel(r"C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Marvin\TSA Account Closure\April24&May24 Ongoing Batch\2024018_TSA_Account_Closure_3rdtNotification.xlsx", sheet_name='TSA_Closure_3rdNotification', index = False)
